# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepak-Kambala/ML/blob/main/Experience_Salary_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('Experience-Salary.csv')
df
# Out:
#      exp(in months)  salary(in thousands)
# 0         18.290293             16.521825
# 1         17.023407             11.666234
# 2         26.343613             23.167255
# 3         19.105834             20.877145
# 4         27.742516             23.166236
# ..              ...                   ...
# 995       22.161741             24.666502
# 996       32.266497             24.160270
# 997       17.039030             19.903797
# 998       25.222124             21.974413
# 999       16.418028             19.634787
#
# [1000 rows x 2 columns]

# %%
plt.xlabel("exp")
plt.ylabel("salary")
plt.scatter(df['exp(in months)'], df['salary(in thousands)'],color='red', marker='.')

# %% [markdown]
# new_df is likely a Series (1D).
#
# But fit() needs X to be 2D ([n_samples, n_features]).
#
# sal (target y) can be 1D.
#
# so you can't simply say, new_df=df['exp(in months)']

# %%
new_df = df.drop('salary(in thousands)', axis=1)
sal =df['salary(in thousands)']

# %%
reg = linear_model.LinearRegression()
reg.fit(new_df,sal)
# Out:
# LinearRegression()

# %%
reg.predict([[12]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([15.07287851])
